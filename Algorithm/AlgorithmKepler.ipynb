# %%
# %load_ext autoreload
# %autoreload 2

# %%
from spectrumProcessorKepler import PowerSpectrumProcessor
from noiseAddition import NoiseAddition
from bestFilters import BestFilters

# %%
noise_sim = NoiseAddition("powerSpectrum//161.pow")

# %%
noise_sim.add_noise()

# %%
noise_sim.plot_noise()

# %%
processor = PowerSpectrumProcessor("NoisyData//161_cams24_vmag4.0.pow")
# "NoisyData//spectrum_4_cams24_vmag12.7.pow"

# %%
processor.load_power_spectrum()

# %%
processor.run_filtering()

# %%
processor.run_baseline_subtraction()
# Out:
# Baseline subtraction completed for all filtered outputs.

# %%
processor.save_results()
# Out:
# Combined CSV saved at: filterOutput\161_cams24_vmag4.0_filter_data.csv

# %%
processor.plot_filtered_outputs()

# %%
bestFilter = BestFilters("filterOutput//161_cams24_vmag4.0_filter_data.csv")

# %%
bestFilter.process_and_plot()
# Out:
# Best three filters saved to: bestFilters\161_cams24_vmag4.0_filter_data_best.csv
# Plot saved to: bestFilters\161_cams24_vmag4.0_filter_data_best_plot.png
