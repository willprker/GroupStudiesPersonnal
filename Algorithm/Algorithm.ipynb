# %%
# %load_ext autoreload
# %autoreload 2

# %%
from spectrumProcessor import PowerSpectrumProcessor
from noiseClass import NoiseAddition

# %%
noise_sim = NoiseAddition("powerSpectrum/output.pow", vmag=15, num_cams=24)

# %%
noise_sim.add_noise()
# Out:
# Noisy data saved to powerSpectrum/output_cams24_vmag15.0.pow

# %%
noise_sim.plot_noise()

# %%
processor = PowerSpectrumProcessor("powerSpectrum//output_cams24_vmag15.0.pow")

# %%
processor.load_power_spectrum()

# %%
processor.run_filtering()
# Out:
# All filtering operations completed.

# %%
processor.run_baseline_subtraction()
# Out:
# Baseline subtraction completed for all filtered outputs.

# %%
processor.save_results()
# Out:
# Combined CSV saved at: .\combinedFilteredData.csv

# %%
processor.plot_filtered_outputs()
